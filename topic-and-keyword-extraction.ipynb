# %% [markdown]
# ## load data

# %%
import pandas as pd
from bs4 import BeautifulSoup
import emoji
import re


def preprocess_text(text: str) -> str:
  soup = BeautifulSoup(text, features="html.parser")
  text = soup.get_text()
  text = text.replace("\n", ". ")
  return text


def remove_url(text: str) -> str:
  return re.sub(r'(https?:\/\/)?([\da-z\.-]+)\.([a-z\.]{2,6})([\/\w \.-]*)', ' ', text)


def preprocess_entity(text: str) -> str:
  text = text.replace("\n", " ")
  return re.sub(r'[@][^\ ]*', '', text)

# %%
news_df = pd.read_csv("post10k.csv", encoding="utf-8")
news_df = news_df.dropna(subset=['text'])
news_df = news_df.reset_index(drop=True)
news_df.text = news_df.text.apply(lambda x: preprocess_text(x))
news_df.text = news_df.text.apply(lambda x: remove_url(x))
news_df['text'] = news_df["text"].apply(lambda x: emoji.replace_emoji(x))

# %%
news_df
# Out:
#        Unnamed: 0  msg_id   entity_id  \
# 0               0    5301  1002094480
# 1               1    5302  1002094480
# 2               2    5304  1002094480
# 3               3    5305  1002094480
# 4               4    5306  1002094480
# ...           ...     ...         ...
# 11078        2217    5732  1150141694
# 11079        2218    5733  1150141694
# 11080        2219    5735  1150141694
# 11081        2220    5736  1150141694
# 11082        2221    5739  1150141694
#
#                                                     text content_type  \
# 0       Яркие фотокарточки первой победы в году уже ж...  media_group
# 1       Кто стал обладателем игровой майки и брендиро...         text
# 2      Тренируемся в традиционном режиме . . Готовимс...        video
# 3      Проведи год вместе с Динамо-Ак Барс . . Предст...        video
# 4      Динамо-Ак Барс  Минчанка. . Кто окажется сильн...        photo
# ...                                                  ...          ...
# 11078  Чистили дорогу-сковырнули таксофон.. . @montaj...        photo
# 11079  Наткнулся на полезный канал от Тимура Евгажуко...        photo
# 11080                                      @montajniklvs  media_group
# 11081  Компания X-Сom совместно c Hyperline приглашае...        photo
# 11082                 Связь в Евпатории. . @montajniklvs  media_group
#
#       keyboard  silent  has_media_spoiler               posted
# 0          NaN       0                  0  2023-01-09 17:10:06
# 1          NaN       0                  0  2023-01-10 14:00:11
# 2          NaN       0                  0  2023-01-10 14:40:25
# 3          NaN       0                  0  2023-01-11 12:30:23
# 4          NaN       0                  0  2023-01-11 16:00:06
# ...        ...     ...                ...                  ...
# 11078      NaN       0                  0  2023-03-27 09:01:43
# 11079      NaN       0                  0  2023-03-27 09:21:34
# 11080      NaN       0                  0  2023-03-27 14:00:54
# 11081      NaN       0                  0  2023-03-27 14:09:43
# 11082      NaN       0                  0  2023-03-27 19:01:42
#
# [11083 rows x 9 columns]

# %%
ent_df = pd.read_csv("entity10k.csv", encoding="utf-8")

ent_df = ent_df.dropna(subset=['about', 'name'])
ent_df = ent_df.reset_index(drop=True)
ent_df.about = ent_df.about.apply(lambda x: preprocess_entity(x))

ent_df
# Out:
#       Unnamed: 0   entity_id  created_with     entity_type      photo_id  \
# 0              0  1610995496           NaN  public_channel  5.472302e+18
# 1              1  1789104687           NaN  public_channel  5.256092e+18
# 2              4  1436274540           NaN  public_channel  5.382082e+18
# 3              5  1164503012           NaN  public_channel           NaN
# 4              9  1652917150           NaN  public_channel  5.224346e+18
# ...          ...         ...           ...             ...           ...
# 8702        9994  1685138688           NaN  public_channel  5.224527e+18
# 8703        9995  1192459940           NaN  public_channel  5.393149e+18
# 8704        9997  1185527198           NaN  public_channel  5.294033e+18
# 8705        9998  1605489168           NaN  public_channel  5.278642e+18
# 8706        9999  1574057669           NaN  public_channel  5.408984e+18
#
#                                               photo_url  \
# 0     https://telegra.ph/file/8bfdab6f783b8dc653ee5.jpg
# 1     https://telegra.ph/file/8e59a247c7bf2fefa3623.jpg
# 2     https://telegra.ph/file/6b5a56d9dcecc1a6512b0.jpg
# 3                                                   NaN
# 4     https://telegra.ph/file/8e21c229d0855e30cad86.jpg
# ...                                                 ...
# 8702  https://telegra.ph/file/ee3480c2badd90cdd285d.jpg
# 8703  https://telegra.ph/file/cc58e72ffad36e7f70da9.jpg
# 8704  https://telegra.ph/file/9f970b5bb0533a8b5d31c.jpg
# 8705  https://telegra.ph/file/faa9d704bbea0ca4f9328.jpg
# 8706  https://telegra.ph/file/17a3fa3ced09f0e29c8c0.jpg
#
#                                   name             username  \
# 0                           PanStandUp           panstandup
# 1                              Perusha             perushag
# 2                  Володимир Назаренко   nazarenkovolodymyr
# 3                                Tania                tania
# 4      Astrolog4U |Астрология|Гороскоп           astrolog4y
# ...                                ...                  ...
# 8702                  Пункт Выдачи ДНР          ozon_wb_dpr
# 8703           КОРПОРАТИВНЫЙ СЕКРЕТАРЬ                nokc1
# 8704                  язычки и темы тг          yazyki_dlya
# 8705  IT channels | каталог IT каналов  itchannels_telegram
# 8706                     GRASSER_STORE         grasser_shop
#
#               access_hash                                              about  \
# 0    -3962254009726019372  Комики из Беларуси в Варшаве (Польша). Делаем ...
# 1     7057200524768072727                                        Продаю лс:
# 2    -4403316951522258700
# 3    -3016471089131185998                 To acquire the username, contact:
# 4    -1395830427450260891  Твой личный Астролог🫂  Реклама:    Закуп и ВП:...
# ...                   ...                                                ...
# 8702  5698232276355410541                                        Новости ПВЗ
# 8703 -7612141659753682724  Информационный канал для членов НОКС, професси...
# 8704  2539500734111985922  подборки темок и языков  по рекламе:   Реклама...
# 8705 -3072196939198662943  по всем вопросам                              ...
# 8706 -3034125807699698426  Магазин тканей и фурнитуры. Опт и розница. г. ...
#
#       ...  cheat_created  ios_ban   scam  verified   fake  hidden  blocked  \
# 0     ...            NaN    False  False     False  False   False    False
# 1     ...            NaN    False  False     False  False   False    False
# 2     ...            NaN    False  False     False  False   False    False
# 3     ...            NaN    False  False     False  False   False    False
# 4     ...            NaN    False  False     False  False   False    False
# ...   ...            ...      ...    ...       ...    ...     ...      ...
# 8702  ...            NaN    False  False     False  False   False    False
# 8703  ...            NaN    False  False     False  False   False    False
# 8704  ...            NaN    False  False     False  False   False    False
# 8705  ...            NaN    False  False     False  False   False    False
# 8706  ...            NaN    False  False     False  False   False    False
#
#       language_code                   birthdate                     created
# 0                be  2022-08-08 15:50:07.000000  2023-01-26 20:20:56.994689
# 1                ru  2023-02-16 13:03:54.000000  2023-02-18 08:30:23.964101
# 2                uk  2020-01-14 12:24:58.000000  2023-01-28 21:30:48.070326
# 3               NaN  2018-08-10 15:18:21.000000  2023-03-23 16:15:02.398859
# 4                ru  2022-08-10 09:33:13.000000  2023-01-26 13:36:00.010200
# ...             ...                         ...                         ...
# 8702             ru  2023-03-14 13:14:24.000000  2023-03-25 15:22:48.378101
# 8703             ru  2018-02-07 19:47:08.000000  2023-01-26 23:21:40.681633
# 8704             ru  2021-09-01 10:53:30.000000  2023-03-05 14:43:58.608290
# 8705            NaN  2022-03-08 14:30:16.000000  2023-01-26 13:02:41.959799
# 8706             ru  2022-03-05 15:24:10.000000  2023-02-04 11:46:59.200875
#
# [8707 rows x 21 columns]

# %% [markdown]
# ## BERTopic

# %% [markdown]
# https://www.kaggle.com/code/falloutbabe/russian-invasion-of-ukraine-news-topic-modeling/notebook

# %%
import pandas as pd
import numpy as np
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
import os
from nltk.corpus import stopwords
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import CountVectorizer
from tqdm import tqdm

import torch

# !pip install umap-learn
# !pip install hdbscan
# !pip install bertopic
# !pip install sentence-transformers
# !pip install emoji==1.7.0

from umap import UMAP
from hdbscan import HDBSCAN
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
# Out:
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.10/dist-packages (0.5.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.11.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.56.4)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.5.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.1)
# Requirement already satisfied: tbb>=2019.0 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (2021.10.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (67.7.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.2.0)
# Requirement already satisfied: hdbscan in /usr/local/lib/python3.10/dist-packages (0.8.33)
# Requirement already satisfied: cython<3,>=0.27 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (0.29.36)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.23.5)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.11.3)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.2.2)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20->hdbscan) (3.2.0)
# Requirement already satisfied: bertopic in /usr/local/lib/python3.10/dist-packages (0.15.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.23.5)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.8.33)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.5.4)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.15.0)
# Requirement already satisfied: cython<3,>=0.27 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.36)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.11.3)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.34.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.15.2+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.17.3)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.10)
# Requirement already satisfied: tbb>=2019.0 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (2021.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.12.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (67.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (17.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2023.6.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.7)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.34.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.17.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.12.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (17.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: emoji==1.7.0 in /usr/local/lib/python3.10/dist-packages (1.7.0)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
docs = news_df.text.to_list()
ents = ent_df.about.to_list()

# %%
umap_model = UMAP(n_neighbors=10, n_components=5, metric='cosine', low_memory=False)
vectorizer_model = CountVectorizer(stop_words=stopwords.words('russian') + stopwords.words('english'))
hdbscan_model = HDBSCAN(min_cluster_size=35, min_samples=10, metric='euclidean', prediction_data=True)

topic_model_ent = BERTopic(umap_model=umap_model,
                       vectorizer_model=vectorizer_model,
                       hdbscan_model=hdbscan_model,
                       nr_topics=40, top_n_words=10, language='multilingual', verbose=True).fit(ents)
# Out:
# Batches:   0%|          | 0/273 [00:00<?, ?it/s]
# 2023-10-11 12:44:21,307 - BERTopic - Transformed documents to Embeddings
# 2023-10-11 12:44:46,349 - BERTopic - Reduced dimensionality
# 2023-10-11 12:44:46,853 - BERTopic - Clustered reduced embeddings
# 2023-10-11 12:44:47,947 - BERTopic - Reduced number of topics from 42 to 40

# %%
umap_model = UMAP(n_neighbors=15, n_components=5, metric='cosine', low_memory=False)
vectorizer_model = CountVectorizer(stop_words=stopwords.words('russian') + stopwords.words('english'))
hdbscan_model = HDBSCAN(min_cluster_size=30, min_samples=5, metric='euclidean', prediction_data=True)

topic_model_post = BERTopic(umap_model=umap_model,
                       vectorizer_model=vectorizer_model,
                       hdbscan_model=hdbscan_model,
                       nr_topics=100, top_n_words=10, language='multilingual', verbose=True).fit(docs)
# Out:
# Batches:   0%|          | 0/347 [00:00<?, ?it/s]
# 2023-10-11 12:16:47,226 - BERTopic - Transformed documents to Embeddings
# 2023-10-11 12:17:01,597 - BERTopic - Reduced dimensionality
# 2023-10-11 12:17:02,104 - BERTopic - Clustered reduced embeddings
# 2023-10-11 12:17:04,504 - BERTopic - Reduced number of topics from 70 to 70

# %%
topic_model_post.get_topic_info()
# Out:
#     Topic  Count                                         Name  \
# 0      -1   3865                        -1_это_россии_года_рф
# 1       0     72  0_предоплату_кидала_мошенники_мошенничества
# 2       1     49                              1_таблетушки___
# 3       2     53          2_франции_пенсионной_реформы_против
# 4       3    852           3_тбилиси_объявлений_цена_животные
# ..    ...    ...                                          ...
# 65     64     54       64_ташкент_tas_авиакомпании_uzbekistan
# 66     65    127                           65_mq_сша_морем_су
# 67     66     97        66_всу_уничтожили_направлении_военных
# 68     67     90               67_германии_dwrussian_евро_фрг
# 69     68    383                  68_сша_украине_украины_нато
#
#                                        Representation  \
# 0   [это, россии, года, рф, области, году, также, ...
# 1   [предоплату, кидала, мошенники, мошенничества,...
# 2                      [таблетушки, , , , , , , , , ]
# 3   [франции, пенсионной, реформы, против, макрон,...
# 4   [тбилиси, объявлений, цена, животные, krayzeml...
# ..                                                ...
# 65  [ташкент, tas, авиакомпании, uzbekistan, вылет...
# 66  [mq, сша, морем, су, беспилотник, беспилотника...
# 67  [всу, уничтожили, направлении, военных, вс, су...
# 68  [германии, dwrussian, евро, фрг, немецкие, deu...
# 69  [сша, украине, украины, нато, россии, это, зая...
#
#                                   Representative_Docs
# 0   [Талоны в ММЦ в Сахарово. 12 февраля 2023 г. п...
# 1   [​ВНИМАНИЕ - МОШЕННИКИ. . Участились случаи мо...
# 2                                  [ , Таблетушки,  ]
# 3   [Сенат Франции принял закон о пенсионной рефор...
# 4   [Я: #СдаюЖильё . В: #Тбилиси. Описание: АРЕНДА...
# ..                                                ...
# 65  [Посадка в международном аэропорту имени Ислам...
# 66  [Намеренное нападение США на российский самоле...
# 67  [Новый брифинг МО РФ. Главное:. . Потери ВСУ н...
# 68  [Что мешает иностранцу найти работу в Германии...
# 69  [Когда же может стать необходимым использовани...
#
# [70 rows x 5 columns]

# %%
topic_model_ent.get_topic_info()
# Out:
#     Topic  Count                                            Name  \
# 0      -1   3751                           -1_https_канал_com_ru
# 1       0    670                       0_связь_всем_вопросам_это
# 2       1    493                   1_https_com_instagram_youtube
# 3       2    476                             2_00_ва_нᴀ_доставка
# 4       3    431                           3_россии_рф_москвы_ru
# 5       4    224              4_рекламы_реклама_рекламе_вопросам
# 6       5    164                    5_новости_сми_самые_новостей
# 7       6    161                   6_одежды_одежда_магазин_бренд
# 8       7    157               7_глава_области_района_республики
# 9       8    129                      8_crypto_nft_крипте_крипто
# 10      9    126           9_рецепты_wildberries_вкусные_десерты
# 11     10    114                        10_дизайн_data_ai_design
# 12     11    114           11_бизнеса_бизнес_наставник_экспертов
# 13     12    107            12_искусство_искусства_арт_искусстве
# 14     13     90          13_telegram_телеграм_официальный_канал
# 15     14     89                      14_игры_game_apple_android
# 16     15     86                       15_книги_блог_книг_книгах
# 17     16     85                         16_новини_україни_зв_та
# 18     17     77     17_психолог_психология_психолога_психологии
# 19     18     73              18_врач_медицины_здоровье_медицине
# 20     19     70                       19_admin_uchun_va_reklama
# 21     20     70       20_инвестиции_инвестициях_экономики_канал
# 22     21     68              21_канал_официальный_channel_банка
# 23     22     68                     22_связь_связи_нами_contact
# 24     23     67           23_футбольного_клуба_headliner_sports
# 25     24     66                         24_юмор_мемы_юмора_меми
# 26     25     57                 25_владелец_owner_призы_отписку
# 27     26     57         26_ielts_english_английский_англійської
# 28     27     56                        27_00_номер_тел_telegram
# 29     28     55                 28_music_музыка_музыку_плейлист
# 30     29     52                   29_owner_𝖺𝖽𝗆𝗂𝗇_владелец_admin
# 31     30     51                  30_канал_https_основной_nowapp
# 32     31     50                     31_канал_канале_channel_всё
# 33     32     49               32_admin_менеджер_менеджеры_админ
# 34     33     47               33_официальный_канал_главы_района
# 35     34     45                34_города_городе_новости_удобном
# 36     35     44  35_сотрудничество_сотрудничества_near_вопросам
# 37     36     43             36_детей_родителей_babyx_schoollink
# 38     37     40             37_beauty_lifestyle_красота_красиво
# 39     38     35      38_недвижимости_недвижимость_рынка_квартир
#
#                                        Representation  \
# 0   [https, канал, com, ru, va, uchun, вопросам, р...
# 1   [связь, всем, вопросам, это, вп, мной, тебе, с...
# 2   [https, com, instagram, youtube, www, twitter,...
# 3   [00, ва, нᴀ, доставка, канал, админ, вопросам,...
# 4   [россии, рф, москвы, ru, новости, канал, москв...
# 5   [рекламы, реклама, рекламе, вопросам, рекламу,...
# 6   [новости, сми, самые, новостей, актуальные, ne...
# 7   [одежды, одежда, магазин, бренд, доставка, инт...
# 8   [глава, области, района, республики, губернато...
# 9   [crypto, nft, крипте, крипто, https, криптовал...
# 10  [рецепты, wildberries, вкусные, десерты, пп, р...
# 11  [дизайн, data, ai, design, learning, ии, pytho...
# 12  [бизнеса, бизнес, наставник, экспертов, продав...
# 13  [искусство, искусства, арт, искусстве, art, фо...
# 14  [telegram, телеграм, официальный, канал, de, t...
# 15  [игры, game, apple, android, турниры, игр, ios...
# 16  [книги, блог, книг, книгах, читаю, связи, года...
# 17  [новини, україни, зв, та, https, язку, ukraine...
# 18  [психолог, психология, психолога, психологии, ...
# 19  [врач, медицины, здоровье, медицине, медицина,...
# 20  [admin, uchun, va, reklama, bo, ko, alaykum, u...
# 21  [инвестиции, инвестициях, экономики, канал, фи...
# 22  [канал, официальный, channel, банка, основной,...
# 23  [связь, связи, нами, contact, обратной, контак...
# 24  [футбольного, клуба, headliner, sports, спорти...
# 25  [юмор, мемы, юмора, меми, смешные, анекдоты, м...
# 26  [владелец, owner, призы, отписку, закупает, вы...
# 27  [ielts, english, английский, англійської, англ...
# 28  [00, номер, тел, telegram, замовлення, 28, uy,...
# 29  [music, музыка, музыку, плейлист, музыки, музы...
# 30  [owner, 𝖺𝖽𝗆𝗂𝗇, владелец, admin, sabr, qiling, ...
# 31  [канал, https, основной, nowapp, channel, bit,...
# 32  [канал, канале, channel, всё, адм, пожаловать,...
# 33  [admin, менеджер, менеджеры, админ, администра...
# 34  [официальный, канал, главы, района, республики...
# 35  [города, городе, новости, удобном, нашего, рек...
# 36  [сотрудничество, сотрудничества, near, вопроса...
# 37  [детей, родителей, babyx, schoollink, игры, де...
# 38  [beauty, lifestyle, красота, красиво, красоты,...
# 39  [недвижимости, недвижимость, рынка, квартир, а...
#
#                                   Representative_Docs
# 0   [Наш сайт weekportal.ru реклама   Подборки 🌈  ...
# 1   [Связь со мной : , связь со мной , по всем воп...
# 2   [💚 Сотрудничество - wx7eacooperation /   🥕 Lik...
# 3   [Оптом электронные испарители 18+💥 Находимся п...
# 4   [Самые интересные новости Иркутской области, Р...
# 5   [По вопросам рекламы:👇  , По вопросам рекламы ...
# 6   [Все самые актуальные новости, Мы здесь новост...
# 7   [🛍ОНЛАЙН-МАГАЗИН «LUX BRAND»  Брендовая одежда...
# 8   [Глава Петровского муниципального района, Глав...
# 9   [🤖 feedback | відправити еБук —   〰️〰️〰️〰️〰️〰️...
# 10  [📌Самые вкусные рецепты по системе минус 60: ▪...
# 11  [🔳Секреты индустрии ИИ изнутри и шаги к успешн...
# 12  [Привет, я Таня - наставник по продвижению и п...
# 13  [Об искусстве, арт-рынке и lifestyle от искусс...
# 14  [Ucellning rasmiy Telegram-kanali  Официальный...
# 15  [Покупаем для вас: 🔥 Playstation Plus 🎮 Игры д...
# 16  [Здесь читают книги, трындят о книгах, и очень...
# 17  [Щодня забезпечуємо лише найважливішими новина...
# 18  [Марина Сыскова. Психолог. Системно-родовой те...
# 19  [🟠Экосистема заботы о вашем здоровье: поликлин...
# 20  [(Rasmiy kanal bizdan uzoqlashmang🥀)  Maqsadim...
# 21  [Рассказываем о фондовом рынке и личных финанс...
# 22  [Thousands of masterminds creating a dark soun...
# 23                       [Связь - , Связь , связь ➜ ]
# 24  [Канал о событиях и цифрах в мире #NBA  По все...
# 25  [Отдушина и место силы для HR'a. Злободневные ...
# 26            [Владелец - , Владелец - , Владелец | ]
# 27  [IELTS listening tips, Videos movies and pract...
# 28  [TOSHKENT UY BOZOR | расмий каналининг QIBRAY ...
# 29  [Здесь ebashit не только андеграунд 🏎️💨  🪐Vibe...
# 30  [ Original made in USA 🇺🇸   Доставка ✔️ Гаран...
# 31  [Основной канал с многими другими аниме ⬇️⬇️⬇️...
# 32  [На канале ты: ✴️ узнаешь как получать ресурс ...
# 33                   [Admin - , Admin:  👤, Admin  🥰👑]
# 34  [Официальный канал администрации муниципальног...
# 35  [Новости города в удобном для вас формате!  Ак...
# 36  [Сотрудничество: , Сотрудничество: , Сотруднич...
# 37  [📚🖍Здесь про достойное и доступное образование...
# 38  [Lifestyle•Beauty•inspiration•aesthetics  💌  t...
# 39  [Страх в недвижимости😉  Дайджест ранка👩🏼‍💻  16...

# %%
topic_model_post.visualize_hierarchy()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cf7c2b9a-18f7-464f-93e9-0d3f9e850a17" class="plotly-graph-div" style="height:1235px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf7c2b9a-18f7-464f-93e9-0d3f9e850a17")) {                    Plotly.newPlot(                        "cf7c2b9a-18f7-464f-93e9-0d3f9e850a17",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.1891169729792278,0.1891169729792278,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9971195338739964,0.9971195338739964,0.0],"xaxis":"x","y":[-35.0,-35.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.000958313345583,1.000958313345583,0.9971195338739964],"xaxis":"x","y":[-25.0,-25.0,-40.0,-40.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.9761611115238129,0.9761611115238129,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.000958313345583,1.0127523462131884,1.0127523462131884,0.9761611115238129],"xaxis":"x","y":[-32.5,-32.5,-60.0,-60.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.0,0.8889716017729176,0.8889716017729176,0.0],"xaxis":"x","y":[-75.0,-75.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.8889716017729176,0.9910085335234112,0.9910085335234112,0.0],"xaxis":"x","y":[-80.0,-80.0,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.0127523462131884,1.0515997933901062,1.0515997933901062,0.9910085335234112],"xaxis":"x","y":[-46.25,-46.25,-87.5,-87.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.0,0.9558308359923857,0.9558308359923857,0.0],"xaxis":"x","y":[-105.0,-105.0,-115.0,-115.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.0,0.9039839141494146,0.9039839141494146,0.0],"xaxis":"x","y":[-135.0,-135.0,-145.0,-145.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.0,0.9656430783066312,0.9656430783066312,0.9039839141494146],"xaxis":"x","y":[-125.0,-125.0,-140.0,-140.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.9656430783066312,0.9741363817371852,0.9741363817371852,0.0],"xaxis":"x","y":[-132.5,-132.5,-155.0,-155.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9558308359923857,1.0050989993237271,1.0050989993237271,0.9741363817371852],"xaxis":"x","y":[-110.0,-110.0,-143.75,-143.75],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.84182342241114,0.84182342241114,0.0],"xaxis":"x","y":[-165.0,-165.0,-175.0,-175.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9511678228358523,0.9511678228358523,0.0],"xaxis":"x","y":[-185.0,-185.0,-195.0,-195.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.9511678228358523,0.958370833714069,0.958370833714069,0.0],"xaxis":"x","y":[-190.0,-190.0,-205.0,-205.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.84182342241114,0.9789293447372291,0.978929 ...

# %%
topic_model_ent.visualize_hierarchy()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3e599744-d05c-43b6-983a-5a3845633733" class="plotly-graph-div" style="height:785px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e599744-d05c-43b6-983a-5a3845633733")) {                    Plotly.newPlot(                        "3e599744-d05c-43b6-983a-5a3845633733",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.8762576314484513,0.8762576314484513,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.7709506915330471,0.7709506915330471,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.8762576314484513,1.01171122628731,1.01171122628731,0.7709506915330471],"xaxis":"x","y":[-10.0,-10.0,-30.0,-30.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.7596775960343382,0.7596775960343382,0.0],"xaxis":"x","y":[-45.0,-45.0,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.8326310676101405,0.8326310676101405,0.0],"xaxis":"x","y":[-65.0,-65.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.8326310676101405,0.9064556148453975,0.9064556148453975,0.0],"xaxis":"x","y":[-70.0,-70.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.7596775960343382,0.9937675771689986,0.9937675771689986,0.9064556148453975],"xaxis":"x","y":[-50.0,-50.0,-77.5,-77.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.0,0.715345711750748,0.715345711750748,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.0,0.8344960681507597,0.8344960681507597,0.715345711750748],"xaxis":"x","y":[-105.0,-105.0,-120.0,-120.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.8344960681507597,0.867228150196465,0.867228150196465,0.0],"xaxis":"x","y":[-112.5,-112.5,-135.0,-135.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.0,0.9165025884074798,0.9165025884074798,0.867228150196465],"xaxis":"x","y":[-95.0,-95.0,-123.75,-123.75],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.0,0.7122681732698061,0.7122681732698061,0.0],"xaxis":"x","y":[-155.0,-155.0,-165.0,-165.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.0,0.8466988247304639,0.8466988247304639,0.7122681732698061],"xaxis":"x","y":[-145.0,-145.0,-160.0,-160.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.0,0.867099980890127,0.867099980890127,0.0],"xaxis":"x","y":[-175.0,-175.0,-185.0,-185.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.8466988247304639,0.9791479053079852,0.9791479053079852,0.867099980890127],"xaxis":"x","y":[-152.5,-152.5,-180.0,-180.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.0,0.8862053942409485,0.8862053942409485,0.0],"xaxis":"x","y":[-215.0,-215.0,-225.0,-225.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.0,0.9026284829314305,0.9026284829314305,0.88620 ...

# %%
topic_model_post.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f1cd7c48-345d-4aaa-a91c-8cb3a2d301f8" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1cd7c48-345d-4aaa-a91c-8cb3a2d301f8")) {                    Plotly.newPlot(                        "f1cd7c48-345d-4aaa-a91c-8cb3a2d301f8",                        [{"customdata":[[0,"\u043f\u0440\u0435\u0434\u043e\u043f\u043b\u0430\u0442\u0443 | \u043a\u0438\u0434\u0430\u043b\u0430 | \u043c\u043e\u0448\u0435\u043d\u043d\u0438\u043a\u0438 | \u043c\u043e\u0448\u0435\u043d\u043d\u0438\u0447\u0435\u0441\u0442\u0432\u0430 | \u043f\u0440\u043e\u0441\u0438\u0442",72],[1,"\u0442\u0430\u0431\u043b\u0435\u0442\u0443\u0448\u043a\u0438 |  |  |  | ",49],[2,"\u0444\u0440\u0430\u043d\u0446\u0438\u0438 | \u043f\u0435\u043d\u0441\u0438\u043e\u043d\u043d\u043e\u0439 | \u0440\u0435\u0444\u043e\u0440\u043c\u044b | \u043f\u0440\u043e\u0442\u0438\u0432 | \u043c\u0430\u043a\u0440\u043e\u043d",53],[3,"\u0442\u0431\u0438\u043b\u0438\u0441\u0438 | \u043e\u0431\u044a\u044f\u0432\u043b\u0435\u043d\u0438\u0439 | \u0446\u0435\u043d\u0430 | \u0436\u0438\u0432\u043e\u0442\u043d\u044b\u0435 | krayzemlibot",852],[4,"\u043e\u0431\u044a\u044f\u0432\u043b\u0435\u043d\u0438\u0439 | \u0431\u0430\u0442\u0443\u043c\u0438 | \u0446\u0435\u043d\u0430 | \u0436\u0438\u0432\u043e\u0442\u043d\u044b\u0435 | krayzemlibot",593],[5,"montajniklvs | 2f | \u043e\u0442\u0434\u0430\u043c | \u0434\u0430\u0440\u043e\u043c | 3a",68],[6,"\u043c\u0438\u043d\u0443\u0442 | \u043f\u0440\u0438\u0432\u0435\u0442 | \u0438\u0441\u0442\u043e\u0440\u0438\u044f | \u0441\u0442\u0430\u0442\u044c\u044f | \u043c\u0430\u0442\u0435\u0440\u0438\u0430\u043b",103],[7,"\u0441\u043f\u0440\u0430\u0432\u043e\u0447\u043d\u0438\u043a\u0435 | 79081716625 | \u043e\u0431\u0440\u0430\u0449\u0430\u0439\u0441\u044f | casper2110 | \u0440\u0430\u0437\u043c\u0435\u0441\u0442\u0438\u0442\u044c",35],[8,"\u0437\u0435\u043c\u043b\u0435\u0442\u0440\u044f\u0441\u0435\u043d\u0438\u044f | \u0437\u0435\u043c\u043b\u0435\u0442\u0440\u044f\u0441\u0435\u043d\u0438\u0435 | sputniktj | \u0442\u0443\u0440\u0446\u0438\u0438 | \u043c\u0430\u0433\u043d\u0438\u0442\u0443\u0434\u043e\u0439",71],[9,"sputniktj | \u0442\u0430\u0434\u0436\u0438\u043a\u0438\u0441\u0442\u0430\u043d\u0430 | \u0440\u0442 | \u0442\u0430\u0434\u0436\u0438\u043a\u0438\u0441\u0442\u0430\u043d | \u0440\u0430\u0445\u043c\u043e\u043d",39],[10,"\u0441\u043c\u0435\u0440\u0442\u043d\u043e\u0441\u0442\u044c | \u0441\u043b\u0443\u0447\u0430\u0435\u0432 | \u043a\u043e\u0440\u0438 | 2020 | \u0437\u0430\u0431\u043e\u043b\u0435\u0432\u0430\u043d\u0438\u044f",64],[11,"\u043d\u043e\u0432\u043e\u0441\u0442\u0438 | \u043e\u0442\u0435\u043b\u0435\u0439 | \u043e\u0442\u0435\u043b\u0438 | \u043e\u0442\u0435\u043b\u044c | \u043e\u0442\u0435\u043b\u0438\u0440\u043e\u0441\u0441\u0438\u0438",102],[12,"\u043f\u043e\u0436\u0430\u0440 | \u043f\u043e\u0436\u0430\u0440\u0430 | \u043c\u0447\u0441 | \u0437\u0434\u0430\u043d\u0438\u0438 | \u043f\u043e\u0441\u0442\u0440\u0430\u0434\u0430\u0432\u0448\u0438\u0445",81],[13,"\u0444\u0438\u043b\u044c\u043c | \u043a\u0438\u043d\u043e | \u043e\u0441\u043a\u0430\u0440 | \u043d\u0430\u0432\u0430\u043b\u044c\u043d\u044b\u0439 | \u044d\u0442\u043e",31],[14,"\u0431\u043e\u0435\u0432\u0438\u043a\u043e\u0432 | \u043f\u0440\u043e\u0432\u0438\u043d\u0446\u0438\u0438 | \u0430\u043b\u044c | \u0438\u0441\u043b\u0430\u043c\u0441\u043a\u043e\u0433\u043e | \u0442\u0430\u043b\u0438\u0431\u044b",55],[15,"bitcoin | \u043a\u0440\u0438\u043f\u0442\u043e\u0432\u0430\u043b\u044e\u0442 | ftx | nft | \u0431\u0438\u0442\u043a\u043e\u0438\u043d\u0430",43],[16,"\u0443\u0440\u0430\u043d\u043e\u043c | \u043e\u0431\u0435\u0434\u043d\u0435\u043d\u043d\u044b\u043c | \u0441\u043d\u0430\u0440\u044 ...

# %%
topic_model_ent.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="91d8ebad-ecff-4e3b-9f8e-ae84dffa8519" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91d8ebad-ecff-4e3b-9f8e-ae84dffa8519")) {                    Plotly.newPlot(                        "91d8ebad-ecff-4e3b-9f8e-ae84dffa8519",                        [{"customdata":[[0,"\u0441\u0432\u044f\u0437\u044c | \u0432\u0441\u0435\u043c | \u0432\u043e\u043f\u0440\u043e\u0441\u0430\u043c | \u044d\u0442\u043e | \u0432\u043f",670],[1,"https | com | instagram | youtube | www",493],[2,"00 | \u0432\u0430 | \u043d\u1d00 | \u0434\u043e\u0441\u0442\u0430\u0432\u043a\u0430 | \u043a\u0430\u043d\u0430\u043b",476],[3,"\u0440\u043e\u0441\u0441\u0438\u0438 | \u0440\u0444 | \u043c\u043e\u0441\u043a\u0432\u044b | ru | \u043d\u043e\u0432\u043e\u0441\u0442\u0438",431],[4,"\u0440\u0435\u043a\u043b\u0430\u043c\u044b | \u0440\u0435\u043a\u043b\u0430\u043c\u0430 | \u0440\u0435\u043a\u043b\u0430\u043c\u0435 | \u0432\u043e\u043f\u0440\u043e\u0441\u0430\u043c | \u0440\u0435\u043a\u043b\u0430\u043c\u0443",224],[5,"\u043d\u043e\u0432\u043e\u0441\u0442\u0438 | \u0441\u043c\u0438 | \u0441\u0430\u043c\u044b\u0435 | \u043d\u043e\u0432\u043e\u0441\u0442\u0435\u0439 | \u0430\u043a\u0442\u0443\u0430\u043b\u044c\u043d\u044b\u0435",164],[6,"\u043e\u0434\u0435\u0436\u0434\u044b | \u043e\u0434\u0435\u0436\u0434\u0430 | \u043c\u0430\u0433\u0430\u0437\u0438\u043d | \u0431\u0440\u0435\u043d\u0434 | \u0434\u043e\u0441\u0442\u0430\u0432\u043a\u0430",161],[7,"\u0433\u043b\u0430\u0432\u0430 | \u043e\u0431\u043b\u0430\u0441\u0442\u0438 | \u0440\u0430\u0439\u043e\u043d\u0430 | \u0440\u0435\u0441\u043f\u0443\u0431\u043b\u0438\u043a\u0438 | \u0433\u0443\u0431\u0435\u0440\u043d\u0430\u0442\u043e\u0440\u0430",157],[8,"crypto | nft | \u043a\u0440\u0438\u043f\u0442\u0435 | \u043a\u0440\u0438\u043f\u0442\u043e | https",129],[9,"\u0440\u0435\u0446\u0435\u043f\u0442\u044b | wildberries | \u0432\u043a\u0443\u0441\u043d\u044b\u0435 | \u0434\u0435\u0441\u0435\u0440\u0442\u044b | \u043f\u043f",126],[10,"\u0434\u0438\u0437\u0430\u0439\u043d | data | ai | design | learning",114],[11,"\u0431\u0438\u0437\u043d\u0435\u0441\u0430 | \u0431\u0438\u0437\u043d\u0435\u0441 | \u043d\u0430\u0441\u0442\u0430\u0432\u043d\u0438\u043a | \u044d\u043a\u0441\u043f\u0435\u0440\u0442\u043e\u0432 | \u043f\u0440\u043e\u0434\u0430\u0432\u0430\u0442\u044c",114],[12,"\u0438\u0441\u043a\u0443\u0441\u0441\u0442\u0432\u043e | \u0438\u0441\u043a\u0443\u0441\u0441\u0442\u0432\u0430 | \u0430\u0440\u0442 | \u0438\u0441\u043a\u0443\u0441\u0441\u0442\u0432\u0435 | art",107],[13,"telegram | \u0442\u0435\u043b\u0435\u0433\u0440\u0430\u043c | \u043e\u0444\u0438\u0446\u0438\u0430\u043b\u044c\u043d\u044b\u0439 | \u043a\u0430\u043d\u0430\u043b | de",90],[14,"\u0438\u0433\u0440\u044b | game | apple | android | \u0442\u0443\u0440\u043d\u0438\u0440\u044b",89],[15,"\u043a\u043d\u0438\u0433\u0438 | \u0431\u043b\u043e\u0433 | \u043a\u043d\u0438\u0433 | \u043a\u043d\u0438\u0433\u0430\u0445 | \u0447\u0438\u0442\u0430\u044e",86],[16,"\u043d\u043e\u0432\u0438\u043d\u0438 | \u0443\u043a\u0440\u0430\u0457\u043d\u0438 | \u0437\u0432 | \u0442\u0430 | https",85],[17,"\u043f\u0441\u0438\u0445\u043e\u043b\u043e\u0433 | \u043f\u0441\u0438\u0445\u043e\u043b\u043e\u0433\u0438\u044f | \u043f\u0441\u0438\u0445\u043e\u043b\u043e\u0433\u0430 | \u043f\u0441\u0438\u0445\u043e\u043b\u043e\u0433\u0438\u0438 | \u043a\u043e\u043d\u0441\u0443\u043b\u044c\u0442\u0430\u0446\u0438\u0438",77],[18,"\u0432\u0440\u0430\u0447 | \u043c\u0435\u0434\u0438\u0446\u0438\u043d\u044b | \u0437\u0434\u043e\u0440\u043e\u0432\u044c\u0435 | \u043c\u0435\u0434\u0438\u0446\u0438\u043d\u0435 | \u043c\u0435\u0434\u0438\u0446\u0438\u043d\u0430",73],[19,"admin | uchun | va | reklama | bo ...

# %%
text = "Канал с рецептами"
topic_model_ent.get_topic_info(topic_model_ent.transform(text)[0][0])
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2023-10-11 13:08:43,519 - BERTopic - Reduced dimensionality
# 2023-10-11 13:08:43,522 - BERTopic - Predicted clusters
#    Topic  Count                                   Name  \
# 0      9    126  9_рецепты_wildberries_вкусные_десерты
#
#                                       Representation  \
# 0  [рецепты, wildberries, вкусные, десерты, пп, р...
#
#                                  Representative_Docs
# 0  [📌Самые вкусные рецепты по системе минус 60: ▪...

# %%
text = "Сдаю жилье в Тбилиси"
topic_model_post.get_topic_info(topic_model_post.transform(text)[0][0])
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2023-10-11 13:09:04,399 - BERTopic - Reduced dimensionality
# 2023-10-11 13:09:04,402 - BERTopic - Predicted clusters
#    Topic  Count                                Name  \
# 0      3    852  3_тбилиси_объявлений_цена_животные
#
#                                       Representation  \
# 0  [тбилиси, объявлений, цена, животные, krayzeml...
#
#                                  Representative_Docs
# 0  [Я: #СдаюЖильё . В: #Тбилиси. Описание: АРЕНДА...

# %% [markdown]
# ## keyBERT
# https://github.com/MaartenGr/KeyBERT

# %%
# !pip install keybert
# Out:
# Collecting keybert
#   Downloading keybert-0.8.3.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sentence-transformers>=0.3.8 in /usr/local/lib/python3.10/dist-packages (from keybert) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.10/dist-packages (from keybert) (1.2.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from keybert) (1.23.5)
# Requirement already satisfied: rich>=10.4.0 in /usr/local/lib/python3.10/dist-packages (from keybert) (13.6.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert) (2.16.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.34.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.15.2+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.17.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.12.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (23.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert) (0.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (17.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2023.6.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (0.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.3.8->keybert) (8.1.7)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.3.8->keybert) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (1.3.0)
# Building wheels for collected packages: keybert
#   Building wheel for keybert (setup.py) ... done
#   Created wheel for keybert: filename=keybert-0.8.3-py3-none-any.whl size=39124 sha256=473c994ec61249bc0e1c05639565ad3d4d5438bd479f53f032a85960785f9b14
#   Stored in directory: /root/.cache/pip/wheels/70/88/07/1a3bc11fd1dd5f89924a02dcbca89a3015e25e8faa31f904dc
# Successfully built keybert
# Installing collected packages: keybert
# Successfully installed keybert-0.8.3

# %%
pip install -U sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.34.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.17.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.12.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (17.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)

# %%
from keybert import KeyBERT
from sentence_transformers import SentenceTransformer

# %%
sentence_model = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")
kw_model = KeyBERT(model=sentence_model)

# %%
news_df
# Out:
#        Unnamed: 0  msg_id   entity_id  \
# 0               0    5301  1002094480
# 1               1    5302  1002094480
# 2               2    5304  1002094480
# 3               3    5305  1002094480
# 4               4    5306  1002094480
# ...           ...     ...         ...
# 11078        2217    5732  1150141694
# 11079        2218    5733  1150141694
# 11080        2219    5735  1150141694
# 11081        2220    5736  1150141694
# 11082        2221    5739  1150141694
#
#                                                     text content_type  \
# 0       Яркие фотокарточки первой победы в году уже ж...  media_group
# 1       Кто стал обладателем игровой майки и брендиро...         text
# 2      Тренируемся в традиционном режиме . . Готовимс...        video
# 3      Проведи год вместе с Динамо-Ак Барс . . Предст...        video
# 4      Динамо-Ак Барс  Минчанка. . Кто окажется сильн...        photo
# ...                                                  ...          ...
# 11078  Чистили дорогу-сковырнули таксофон.. . @montaj...        photo
# 11079  Наткнулся на полезный канал от Тимура Евгажуко...        photo
# 11080                                      @montajniklvs  media_group
# 11081  Компания X-Сom совместно c Hyperline приглашае...        photo
# 11082                 Связь в Евпатории. . @montajniklvs  media_group
#
#       keyboard  silent  has_media_spoiler               posted
# 0          NaN       0                  0  2023-01-09 17:10:06
# 1          NaN       0                  0  2023-01-10 14:00:11
# 2          NaN       0                  0  2023-01-10 14:40:25
# 3          NaN       0                  0  2023-01-11 12:30:23
# 4          NaN       0                  0  2023-01-11 16:00:06
# ...        ...     ...                ...                  ...
# 11078      NaN       0                  0  2023-03-27 09:01:43
# 11079      NaN       0                  0  2023-03-27 09:21:34
# 11080      NaN       0                  0  2023-03-27 14:00:54
# 11081      NaN       0                  0  2023-03-27 14:09:43
# 11082      NaN       0                  0  2023-03-27 19:01:42
#
# [11083 rows x 9 columns]

# %%
news_df2 = news_df.copy()
news_df2 = news_df2[news_df2.text.str.len() > 200]

# %%
news_df2 = news_df2.reset_index(drop=True)
news_df2
# Out:
#       Unnamed: 0  msg_id   entity_id  \
# 0              1    5302  1002094480
# 1              3    5305  1002094480
# 2              4    5306  1002094480
# 3             19    5323  1002094480
# 4             25    5337  1002094480
# ...          ...     ...         ...
# 8286        2174    5642  1150141694
# 8287        2208    5711  1150141694
# 8288        2214    5727  1150141694
# 8289        2218    5733  1150141694
# 8290        2220    5736  1150141694
#
#                                                    text content_type keyboard  \
# 0      Кто стал обладателем игровой майки и брендиро...         text      NaN
# 1     Проведи год вместе с Динамо-Ак Барс . . Предст...        video      NaN
# 2     Динамо-Ак Барс  Минчанка. . Кто окажется сильн...        photo      NaN
# 3     Одерживаем победу сегодня! . . Ждём вас на наш...        photo      NaN
# 4     Время брать реванш! . . Отправляемся в Нижний ...        video      NaN
# ...                                                 ...          ...      ...
# 8286  ВидеонаблЯдение на автобазе.. Собственно, чёрн...  media_group      NaN
# 8287  Неумолимая ярость стихии, сдобренная нарушение...  media_group      NaN
# 8288  Межсетевое взаимодействие в сетях на базе TCP-...  web_preview      NaN
# 8289  Наткнулся на полезный канал от Тимура Евгажуко...        photo      NaN
# 8290  Компания X-Сom совместно c Hyperline приглашае...        photo      NaN
#
#       silent  has_media_spoiler               posted
# 0          0                  0  2023-01-10 14:00:11
# 1          0                  0  2023-01-11 12:30:23
# 2          0                  0  2023-01-11 16:00:06
# 3          0                  0  2023-01-13 20:31:24
# 4          0                  0  2023-01-16 11:20:25
# ...      ...                ...                  ...
# 8286       0                  0  2023-03-17 09:01:05
# 8287       0                  0  2023-03-25 09:01:53
# 8288       0                  0  2023-03-26 20:26:30
# 8289       0                  0  2023-03-27 09:21:34
# 8290       0                  0  2023-03-27 14:09:43
#
# [8291 rows x 9 columns]

# %%
kw_model.extract_keywords(news_df2.loc[38].text, keyphrase_ngram_range=(1, 1), stop_words=None)
# Out:
# [('спектра', 0.5545),
#  ('спектре', 0.5515),
#  ('частотам', 0.4867),
#  ('пикометр', 0.4634),
#  ('гигаметр', 0.441)]

# %%
news_df2.loc[38].text
# Out:
# 'Диапазон видимого света на электромагнитном спектре (Reddit). . За нижний порог спектра взята длина волны в 1 пикометр (10⁻¹² м), а за верхний — 1 гигаметр (10⁹ м). Видимый свет по разным оценкам располагается в диапазоне от 380 до 780 нанометров (10⁻⁹ м). . В нашем старом посте можно посмотреть наглядное расположение электромагнитного спектра по частотам'
